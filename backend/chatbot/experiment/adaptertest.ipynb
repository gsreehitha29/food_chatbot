# %%
from fastmcp import Client


class MCPAdapter:

    def __init__(self):

        self.menu_client = Client(
            "http://localhost:8001/menu_mcp"
        )

        self.order_client = Client(
            "http://localhost:8002/order_mcp"
        )

        self.faq_client = Client(
            "http://localhost:8003/faq_mcp"
        )

        self.sheets_client = Client(
            "http://localhost:8004/sheets_mcp"
        )



mcp = MCPAdapter()
